# %% [markdown]
# # Support Vector Machines (SVM) — Complete Hands-On Question Notebook
#
# **For:** Machine Learning Lab — B.Tech / M.Tech
# **Type:** Student exercise notebook
# **Solutions:** Not included
#
# ## Coverage
# Geometry, hyperplanes, margins, support vectors, hard/soft margin, slack, hinge loss, SVM from scratch, scaling, linear/poly/RBF/sigmoid kernels, C, gamma, degree, GridSearchCV, RandomizedSearchCV, multiclass SVM, imbalanced data, decision scores, probability estimates, SVR, One-Class SVM, custom/precomputed kernels, debugging, model diagnosis, and integrated challenges.
#
# ## Student rules
# - Complete every `TODO` cell.
# - Run all completed cells before submission.
# - Add a short interpretation below every plot/table.
# - Use `random_state=42` unless instructed otherwise.
# - Never use the final test set to select hyperparameters.

# %% [markdown]
# ## 0. Setup

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import (
    make_blobs, make_classification, make_moons, make_circles,
    load_breast_cancer, load_iris, load_digits
)
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.svm import SVC, LinearSVC, SVR, OneClassSVM
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, confusion_matrix, ConfusionMatrixDisplay,
    mean_absolute_error, mean_squared_error, r2_score
)
print('Setup complete.')

# %% [markdown]
# # Part 1 — SVM Geometry
#
# ## Exercise 1 — Decision function
# Given the hyperplane `2*x1 - x2 + 1 = 0`, use `w=[2,-1]`, `b=1` and points `A=(1,1)`, `B=(-1,2)`, `C=(0,-2)`, `D=(2,5)`.
#
# Tasks:
# 1. Compute `f(x) = w^T x + b`.
# 2. Predict `+1` when score > 0 and `-1` when score < 0.
# 3. Identify which point has the smallest absolute decision score.

# %%
w = np.array([2.0, -1.0])
b = 1.0
points = np.array([[1,1],[-1,2],[0,-2],[2,5]])

scores = None       # TODO
predictions = None  # TODO
print('scores:', scores)
print('predictions:', predictions)

# %% [markdown]
# ## Exercise 2 — Plot a hyperplane
# Plot the hyperplane `2*x1 - x2 + 1 = 0`, all four points, their predicted class, and the normal vector `w`.
#
# Answer:
# - Why is `w` perpendicular to the hyperplane?
# - What happens if only `b` changes?
# - What happens if the direction of `w` changes?

# %%
# TODO: Exercise 2

# %% [markdown]
# ## Exercise 3 — Distance to a hyperplane
# Use `distance = abs(w^T x + b) / ||w||`.
#
# Compute the distance of every point in Exercise 1 from the hyperplane and identify the nearest observation. Explain why near-boundary observations matter in SVM.

# %%
w_norm = None       # TODO
distances = None    # TODO
print('||w|| =', w_norm)
print('distances =', distances)

# %% [markdown]
# # Part 2 — Maximum Margin and Support Vectors

# %% [markdown]
# ## Exercise 4 — Multiple valid separators
# Use the starter dataset. Plot at least three different straight lines that separate the classes reasonably well.
#
# Then answer: If several lines have identical training accuracy, what extra criterion does SVM use to choose among them?

# %%
X_sep, y_sep = make_blobs(n_samples=60, centers=2, cluster_std=0.75, random_state=12)
# TODO: plot points and at least 3 candidate separators

# %% [markdown]
# ## Exercise 5 — Support vectors and margin lines
# Train `SVC(kernel='linear', C=1000)` on `X_sep, y_sep`.
#
# Tasks:
# - print `support_vectors_`, `support_`, `n_support_`;
# - plot decision boundary;
# - plot both margin lines corresponding to decision scores +1 and -1;
# - circle the support vectors.

# %%
svm_linear = None   # TODO
# TODO: fit, inspect and visualize

# %% [markdown]
# ## Exercise 6 — Remove non-support vectors
# Remove 20% of training observations that are not support vectors. Retrain the same SVM and compare old/new `w`, `b`, and decision boundaries.
#
# Did the boundary change significantly? Explain.

# %%
# TODO: Exercise 6

# %% [markdown]
# ## Exercise 7 — Remove a support vector
# Remove exactly one support vector, retrain, and compare with the original boundary.
#
# Why can deleting one support vector affect the model more than deleting several distant points?

# %%
# TODO: Exercise 7

# %% [markdown]
# ## Exercise 8 — Margin width
# For a canonical linear SVM, total margin width is `2 / ||w||`.
#
# Extract `coef_`, compute `||w||`, total margin width, and half-margin. Compare the half-margin with the geometric distance of the support vectors from the boundary.

# %%
# TODO: Exercise 8

# %% [markdown]
# # Part 3 — Hard Margin, Soft Margin, C and Hinge Loss

# %% [markdown]
# ## Exercise 9 — Hard-margin sensitivity to an outlier
# Use the starter data, which contains a deliberately difficult/outlier point.
#
# Train linear SVMs with `C = [0.01, 0.1, 1, 100, 10000]`.
#
# For each model record:
# - training accuracy,
# - number of support vectors,
# - margin width,
# - decision boundary.
#
# Explain which values tolerate violations and which aggressively try to fit the difficult point.

# %%
X_soft, y_soft = make_blobs(
    n_samples=90, centers=[(-2,-2),(2,2)], cluster_std=0.9, random_state=42
)
X_soft = np.vstack([X_soft, [2.7, 2.7]])
y_soft = np.append(y_soft, 0)
# TODO

# %% [markdown]
# ## Exercise 10 — Implement hinge loss
# Implement `max(0, 1 - y*score)`.
#
# Evaluate these `(y, score)` pairs:
# `(1,2.0)`, `(1,0.7)`, `(1,-0.5)`, `(-1,-2.0)`, `(-1,-0.2)`, `(-1,1.5)`.
#
# For each, label it as:
# - correct and outside margin,
# - correct but inside margin,
# - misclassified.

# %%
def hinge_loss(y, score):
    # TODO
    pass

examples = [(1,2.0),(1,0.7),(1,-0.5),(-1,-2.0),(-1,-0.2),(-1,1.5)]
# TODO

# %% [markdown]
# ## Exercise 11 — Plot hinge loss
# Plot hinge loss for `z = y*f(x)` over `[-3, 3]`. Mark `z=0` and `z=1`. Annotate misclassified, inside-margin, and outside-margin regions.

# %%
# TODO: Exercise 11

# %% [markdown]
# ## Exercise 12 — C as a regularization trade-off
# Construct a results table for several values of C containing:
# - C,
# - train accuracy,
# - validation accuracy,
# - support-vector count,
# - margin width.
#
# Then answer: Does larger C mean stronger or weaker regularization? What practical behavior changes as C increases?

# %%
# TODO: Exercise 12

# %% [markdown]
# # Part 4 — Implement Linear SVM From Scratch

# %% [markdown]
# ## Exercise 13 — Scratch decision function
# Write `decision_function_scratch(X, w, b)` returning `X @ w + b`. Do not use scikit-learn.

# %%
def decision_function_scratch(X, w, b):
    # TODO
    pass

# %% [markdown]
# ## Exercise 14 — Scratch predictions
# Write `predict_svm_scratch(X, w, b)` returning labels in {-1, +1}.

# %%
def predict_svm_scratch(X, w, b):
    # TODO
    pass

# %% [markdown]
# ## Exercise 15 — Train a linear SVM using sub-gradient descent
# Implement a class that optimizes a regularized hinge-loss objective.
#
# Required methods:
# - `fit(X, y)`
# - `decision_function(X)`
# - `predict(X)`
#
# Also store `loss_history` so optimization can be visualized. Convert labels to {-1,+1} before training.

# %%
class MyLinearSVM:
    def __init__(self, learning_rate=0.001, lambda_param=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.lambda_param = lambda_param
        self.epochs = epochs
        self.loss_history = []

    def fit(self, X, y):
        # TODO
        pass

    def decision_function(self, X):
        # TODO
        pass

    def predict(self, X):
        # TODO
        pass

# %% [markdown]
# ## Exercise 16 — Visualize training progress
# Modify your scratch implementation to save `(w,b)` at epochs 1, 5, 20, 100, 500 and final epoch.
#
# Plot:
# - decision-boundary evolution,
# - training objective/loss vs epoch.
#
# Then deliberately try an overly large learning rate and too few epochs. Describe the failure modes.

# %%
# TODO: Exercise 16

# %% [markdown]
# ## Exercise 17 — Scratch SVM vs sklearn SVM
# Compare your scratch model with `SVC(kernel='linear')` using:
# - test accuracy,
# - prediction disagreement rate,
# - decision-boundary shape,
# - training time.
#
# Explain why the numerical solutions may not be exactly identical.

# %%
# TODO: Exercise 17

# %% [markdown]
# # Part 5 — Feature Scaling

# %% [markdown]
# ## Exercise 18 — Why scaling matters
# The starter dataset multiplies one feature by 1000.
#
# Compare RBF SVM:
# 1. without scaling,
# 2. with `StandardScaler` inside a pipeline.
#
# Report test accuracy and number of support vectors. Explain why a feature with a much larger numeric scale can dominate distance-based kernels.

# %%
X_scale, y_scale = make_classification(
    n_samples=500, n_features=2, n_redundant=0, n_informative=2,
    n_clusters_per_class=1, class_sep=1.3, random_state=42
)
X_scale[:, 1] *= 1000
# TODO

# %% [markdown]
# # Part 6 — Nonlinear SVM and Kernels

# %% [markdown]
# ## Exercise 19 — Logistic Regression vs linear SVM vs RBF SVM
# Use `make_moons`. Compare:
# - Logistic Regression,
# - `SVC(kernel='linear')`,
# - `SVC(kernel='rbf')`.
#
# Plot all decision boundaries and report train/test accuracy.
#
# Explain:
# - why the first two struggle,
# - why RBF can succeed,
# - why this does NOT imply that SVM is universally better than Logistic Regression.

# %%
X_moons, y_moons = make_moons(n_samples=500, noise=0.18, random_state=42)
# TODO

# %% [markdown]
# ## Exercise 20 — Explicit nonlinear transformation
# Use `make_circles`. First train a linear SVM in the original 2D space. Then create `z = x1**2 + x2**2`.
#
# Tasks:
# - plot the original circles,
# - inspect the transformed z values,
# - optionally create a 3D plot `(x1,x2,z)`,
# - explain how this motivates the kernel trick.

# %%
X_circles, y_circles = make_circles(
    n_samples=500, factor=0.35, noise=0.08, random_state=42
)
# TODO

# %% [markdown]
# ## Exercise 21 — Compare kernel families
# On the same nonlinear train/test split compare:
# - linear,
# - polynomial,
# - RBF,
# - sigmoid.
#
# Create a table with train accuracy, test accuracy and number of support vectors. Explain why no kernel is best for every dataset.

# %%
# TODO: Exercise 21

# %% [markdown]
# # Part 7 — Hyperparameters: C, gamma and Polynomial Degree

# %% [markdown]
# ## Exercise 22 — Effect of gamma
# For an RBF SVM, test `gamma = [0.001, 0.01, 0.1, 1, 10, 100]` while keeping `C=1`.
#
# For each setting:
# - plot the boundary,
# - report train and test accuracy,
# - report support-vector count.
#
# Identify underfitting and likely overfitting settings. Explain why high gamma produces local influence.

# %%
# TODO: Exercise 22

# %% [markdown]
# ## Exercise 23 — Joint C-gamma experiment
# Use `C = [0.1,1,10,100]` and `gamma = [0.01,0.1,1,10]`.
#
# Create a DataFrame containing:
# - C,
# - gamma,
# - train score,
# - validation score,
# - support-vector count.
#
# Identify one underfit, one reasonable, and one likely overfit configuration. Do not use the final test set.

# %%
# TODO: Exercise 23

# %% [markdown]
# ## Exercise 24 — Polynomial degree
# For polynomial SVM test degree 2 through 6. Compare training score, validation score, support-vector count, and visual complexity.
#
# Does larger degree always improve generalization?

# %%
# TODO: Exercise 24

# %% [markdown]
# # Part 8 — Cross-Validation and Hyperparameter Search

# %% [markdown]
# ## Exercise 25 — GridSearchCV on Breast Cancer Wisconsin
# Build `StandardScaler -> SVC`.
#
# Search:
# - kernel: `linear`, `rbf`
# - C: `0.01, 0.1, 1, 10, 100`
# - gamma: `0.001, 0.01, 0.1, 1, 'scale'`
#
# Requirements:
# 1. Create train/test split once.
# 2. Run grid search only on training data.
# 3. Print best parameters and best CV score.
# 4. Evaluate the chosen model once on test data.
# 5. Show confusion matrix and classification report.

# %%
data = load_breast_cancer()
X_bc, y_bc = data.data, data.target
# TODO

# %% [markdown]
# ## Exercise 26 — Analyze cv_results_
# Convert `grid.cv_results_` to a DataFrame. Sort by validation score and show the top 10 settings. Inspect `mean_fit_time` and discuss whether the best model is also the slowest.

# %%
# TODO: Exercise 26

# %% [markdown]
# ## Exercise 27 — RandomizedSearchCV
# Repeat model selection using `RandomizedSearchCV`. Compare:
# - best validation score,
# - best parameters,
# - configurations evaluated,
# - runtime.
#
# When is randomized search preferable to exhaustive grid search?

# %%
# TODO: Exercise 27

# %% [markdown]
# # Part 9 — Multiclass SVM

# %% [markdown]
# ## Exercise 28 — Iris multiclass classification
# Train an RBF SVM on Iris. Report:
# - accuracy,
# - confusion matrix,
# - per-class precision,
# - per-class recall,
# - per-class F1.
#
# Which class pair is hardest to separate? How does SVC perform multiclass training internally?

# %%
iris = load_iris()
X_iris, y_iris = iris.data, iris.target
# TODO

# %% [markdown]
# ## Exercise 29 — One-vs-One classifier count
# Write a function for `K*(K-1)/2` and evaluate it for K = 3, 5, 10, 100.
#
# Discuss the consequence as the number of classes becomes large.

# %%
def ovo_classifier_count(k):
    # TODO
    pass

# %% [markdown]
# ## Exercise 30 — Digits: RBF SVC vs LinearSVC
# Use `load_digits`. Compare RBF SVC and LinearSVC using:
# - test accuracy,
# - training time,
# - prediction time.
#
# Explain why the faster or more accurate model can depend on dataset size and geometry.

# %%
digits = load_digits()
X_digits, y_digits = digits.data, digits.target
# TODO

# %% [markdown]
# # Part 10 — Class Imbalance

# %% [markdown]
# ## Exercise 31 — Balanced class weights
# Use the 95:5 dataset below. Compare ordinary SVC with `class_weight='balanced'`.
#
# Report:
# - accuracy,
# - minority precision,
# - minority recall,
# - minority F1,
# - confusion matrix.
#
# Explain why accuracy alone can be misleading.

# %%
X_imb, y_imb = make_classification(
    n_samples=1500, n_features=10, n_informative=6, n_redundant=2,
    weights=[0.95,0.05], class_sep=1.2, random_state=42
)
# TODO

# %% [markdown]
# ## Exercise 32 — Manual class weights
# Test `{0:1,1:2}`, `{0:1,1:5}`, `{0:1,1:10}`.
#
# Compare minority precision and recall. What trade-off appears as minority-class weight increases?

# %%
# TODO: Exercise 32

# %% [markdown]
# # Part 11 — Decision Function and Probability

# %% [markdown]
# ## Exercise 33 — Decision scores
# For 10 test samples show:
# - true label,
# - predicted label,
# - decision-function score.
#
# Sort by absolute decision score. Which observations are closest to the boundary? Is the raw score a probability?

# %%
# TODO: Exercise 33

# %% [markdown]
# ## Exercise 34 — Probability estimates
# Train `SVC(probability=True)`. Compare `decision_function` and `predict_proba` for the same observations. Measure training time with and without probability estimation.
#
# When are calibrated probabilities actually useful?

# %%
# TODO: Exercise 34

# %% [markdown]
# # Part 12 — Support Vector Regression (SVR)

# %% [markdown]
# ## Exercise 35 — Compare SVR kernels
# Use noisy `y = sin(x) + noise`. Train linear, polynomial, and RBF SVR.
#
# Report:
# - MAE,
# - RMSE,
# - R2,
# - prediction plots.
#
# Which kernel captures the nonlinear structure best?

# %%
rng = np.random.RandomState(42)
X_svr = np.sort(6 * rng.rand(160,1), axis=0)
y_svr = np.sin(X_svr).ravel() + 0.18 * rng.randn(160)
# TODO

# %% [markdown]
# ## Exercise 36 — Epsilon in SVR
# Test `epsilon = [0.01,0.1,0.3,0.5]`.
#
# Compare MAE, number of support vectors, and fitted curves. Explain why a wider epsilon-insensitive tube can reduce support-vector count.

# %%
# TODO: Exercise 36

# %% [markdown]
# ## Exercise 37 — C in SVR
# Test `C = [0.1,1,10,100]` with kernel and gamma fixed. Compare generalization and explain how the role of C is related in SVC and SVR.

# %%
# TODO: Exercise 37

# %% [markdown]
# # Part 13 — One-Class SVM / Novelty Detection

# %% [markdown]
# ## Exercise 38 — Synthetic anomaly detection
# Use normal observations around the origin and distant anomalies. Train One-Class SVM and plot detected normal/anomalous observations and decision regions.
#
# Investigate `nu` and `gamma`.

# %%
rng = np.random.RandomState(42)
X_normal = 0.35 * rng.randn(300,2)
X_anomaly = rng.uniform(low=-4, high=4, size=(25,2))
# TODO

# %% [markdown]
# ## Exercise 39 — Effect of nu
# Try `nu = [0.01,0.05,0.1,0.2,0.4]`. Record how many observations are predicted as anomalies. Explain the trend.

# %%
# TODO: Exercise 39

# %% [markdown]
# # Part 14 — Model Diagnosis

# %% [markdown]
# ## Exercise 40 — Underfitting and overfitting diagnosis
# Given:
#
# | Model | Train Accuracy | Validation Accuracy |
# |---|---:|---:|
# | A | 0.71 | 0.69 |
# | B | 0.95 | 0.92 |
# | C | 1.00 | 0.78 |
#
# Identify likely underfitting, balanced, and overfitting models. For an RBF SVM propose sensible C/gamma changes for each situation.

# %%
# Reasoning task; optional experiment

# %% [markdown]
# ## Exercise 41 — Support-vector fraction
# Compute `number_of_support_vectors / number_of_training_samples` across:
# - easy vs hard data,
# - low vs high C,
# - low vs high gamma.
#
# Can support-vector fraction alone prove that a model is overfitting? Explain.

# %%
# TODO: Exercise 41

# %% [markdown]
# # Part 15 — Compare SVM With Other Models

# %% [markdown]
# ## Exercise 42 — Logistic Regression vs Linear SVM vs RBF SVM
# Create:
# 1. an approximately linearly separable dataset,
# 2. a strongly nonlinear dataset.
#
# Compare all three models in terms of accuracy, boundary shape, runtime and interpretability.
#
# Why is the statement “SVM is better than Logistic Regression” incorrect as a universal claim?

# %%
# TODO: Exercise 42

# %% [markdown]
# # Part 16 — Advanced Kernel Tasks

# %% [markdown]
# ## Exercise 43 — Custom kernel
# Create a custom polynomial-like kernel accepted by `SVC(kernel=my_kernel)`. It must accept matrices X and Y and return a Gram matrix.
#
# Compare it with the built-in polynomial kernel. What mathematical properties should a valid kernel ideally satisfy?

# %%
def my_kernel(X, Y):
    # TODO: return Gram matrix
    pass

# %% [markdown]
# ## Exercise 44 — Precomputed kernel
# Manually build a training Gram matrix and fit `SVC(kernel='precomputed')`. Then construct the test-vs-training kernel matrix for prediction.
#
# Why are the train Gram matrix and test kernel matrix shaped differently?

# %%
# TODO: Exercise 44

# %% [markdown]
# ## Exercise 45 — High-dimensional classification
# Use the starter data to compare:
# - LinearSVC,
# - SVC with linear kernel,
# - RBF SVC.
#
# Measure accuracy, fit time, prediction time and scaling sensitivity. Why are linear SVMs often attractive for high-dimensional text-style data?

# %%
X_hd, y_hd = make_classification(
    n_samples=700, n_features=500, n_informative=40, n_redundant=20,
    random_state=42
)
# TODO

# %% [markdown]
# # Part 17 — Debugging and Methodology

# %% [markdown]
# ## Exercise 46 — Detect data leakage
# A student does:
#
# ```python
# scaler = StandardScaler()
# X = scaler.fit_transform(X)
# X_train, X_test, y_train, y_test = train_test_split(X, y)
# ```
#
# Explain the issue and rewrite the workflow correctly using a Pipeline.

# %%
# TODO: Exercise 46

# %% [markdown]
# ## Exercise 47 — Test-set tuning mistake
# A student repeatedly changes C and gamma by checking test accuracy and then reports the highest test score.
#
# Explain:
# 1. what is wrong,
# 2. what information leaked,
# 3. the correct model-selection workflow.

# %%
# Explanation task

# %% [markdown]
# ## Exercise 48 — Unscaled heterogeneous features
# Features have ranges:
# - Age: 18–70
# - Income: 20,000–5,000,000
# - Score: 0–1
#
# An RBF SVM performs poorly without scaling. Explain why and design a corrected pipeline.

# %%
# TODO: Exercise 48

# %% [markdown]
# ## Exercise 49 — 100% training accuracy trap
# Construct a nonlinear dataset and use very high C and gamma to create an extremely complex RBF boundary.
#
# Show train accuracy, test accuracy and the boundary. Explain why 100% training accuracy can indicate overfitting rather than success.

# %%
# TODO: Exercise 49

# %% [markdown]
# # Part 18 — Integrated Hands-On Challenges

# %% [markdown]
# ## Challenge 1 — Full binary SVM pipeline
# Choose any binary dataset and complete:
# 1. class-balance inspection,
# 2. train/test split,
# 3. scaling pipeline,
# 4. linear vs RBF comparison,
# 5. cross-validated tuning,
# 6. final test accuracy/precision/recall/F1,
# 7. confusion matrix,
# 8. support-vector inspection,
# 9. decision-score inspection,
# 10. final model justification.
#
# Restriction: final test data may be evaluated only after model selection is complete.

# %%
# TODO: Challenge 1

# %% [markdown]
# ## Challenge 2 — Visual SVM laboratory
# Create one coherent visual experiment demonstrating:
# - separating hyperplane,
# - positive and negative margins,
# - support vectors,
# - effect of C,
# - effect of gamma,
# - linear vs nonlinear boundary,
# - one clearly overfit RBF boundary.
#
# Add 2–3 lines of interpretation under every figure.

# %%
# TODO: Challenge 2

# %% [markdown]
# ## Challenge 3 — Mini experiment report
# Create a compact report answering:
# - What problem was solved?
# - Why was SVM suitable?
# - Was scaling required?
# - Which kernel was selected?
# - How were C and gamma selected?
# - What did support vectors reveal?
# - Did the model underfit or overfit?
# - Which evaluation metric mattered most?
# - What would you try next?

# %%
# TODO: Challenge 3

# %% [markdown]
# # Part 19 — Viva / Oral Questions
#
# Prepare answers without notes:
#
# 1. What is the geometric objective of SVM?
# 2. Why are support vectors special?
# 3. What is the relationship between ||w|| and margin width?
# 4. Hard margin vs soft margin?
# 5. What does a slack variable represent?
# 6. What does C control?
# 7. Does large C mean stronger regularization?
# 8. What is hinge loss?
# 9. Can a correctly classified point have nonzero hinge loss?
# 10. Why does feature scaling matter?
# 11. What is a kernel?
# 12. What is the kernel trick?
# 13. Why can RBF SVM create nonlinear boundaries?
# 14. What does gamma control?
# 15. What happens when gamma is extremely high?
# 16. What happens when gamma is extremely low?
# 17. SVC(kernel='linear') vs LinearSVC?
# 18. How does SVC handle multiclass classification?
# 19. Does SVM naturally output probabilities?
# 20. What is Support Vector Regression?
# 21. What does epsilon mean in SVR?
# 22. What is One-Class SVM?
# 23. Why can 100% training accuracy still be poor?
# 24. Why should test data not be used for tuning?
# 25. Why can kernel SVM be expensive on very large datasets?
# 26. Can SVM work when features outnumber observations?
# 27. Why is the dual formulation useful for kernels?
# 28. Why do only some training observations contribute to the final dual decision function?
# 29. What is a Gram matrix?
# 30. What is the difference between separability in input space and transformed feature space?

# %% [markdown]
# # Suggested TA Rubric
#
# | Component | Weight |
# |---|---:|
# | Geometry, margins, support vectors | 10% |
# | Soft margin, C, hinge loss | 10% |
# | Scratch SVM | 20% |
# | Scaling and kernels | 15% |
# | Hyperparameter tuning | 15% |
# | Multiclass and imbalance | 10% |
# | SVR and One-Class SVM | 10% |
# | Integrated challenge + interpretation | 10% |
#
# ## Final reflection
# In 5–8 sentences explain in your own words: **What does SVM optimize, what makes support vectors special, and how do C, kernels and gamma collectively determine the final classifier?**

# %% [markdown]
# ---
#
# # Story-Based SVM Case Study — Smart Factory Quality Inspector
#
# A smartphone manufacturing company produces thousands of display panels every day. At the end of the production line, each panel is tested using multiple sensors.
#
# For every panel, the system records:
#
# - `Surface_Roughness`
# - `Light_Transmission`
# - `Pixel_Error_Count`
# - `Thickness`
# - `Temperature_During_Production`
#
# Each panel is finally labelled as:
#
# - **0 → Good**
# - **1 → Defective**
#
# The company currently uses a simple rule-based system, but engineers notice that some defective displays have measurements very similar to good displays. The relationship between sensor readings and defects also appears to be **non-linear**.
#
# Your team has been asked to build an **SVM-based automatic quality inspection system**.
#
# ## Learning Objective
#
# By completing this case study, you should understand how the following components affect an SVM classifier:
#
# \[
# \boxed{
# \text{Margin}
# +
# \text{Support Vectors}
# +
# C
# +
# \text{Kernel}
# +
# \gamma
# }
# \]
#
# You will also practice model evaluation, hyperparameter tuning, class imbalance handling, and engineering decision-making.

# %% [markdown]
# ## Starter Dataset

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_samples=1200,
    n_features=5,
    n_informative=4,
    n_redundant=1,
    n_clusters_per_class=2,
    class_sep=1.0,
    flip_y=0.05,
    weights=[0.80, 0.20],
    random_state=42
)

feature_names = [
    "Surface_Roughness",
    "Light_Transmission",
    "Pixel_Error_Count",
    "Thickness",
    "Temperature"
]

# %% [markdown]
# ## Task 1 — Understand the Dataset
#
# Inspect the dataset and answer the following:
#
# 1. What is the number of samples in the dataset?
# 2. How many input features are available?
# 3. Is the dataset balanced or imbalanced?
# 4. What percentage of samples belong to the defective class?
# 5. Why can **accuracy alone be misleading** for this problem?

# %%
# TODO: Inspect the dataset and class distribution

# %% [markdown]
# ## Task 2 — Prepare the Dataset
#
# Split the dataset into training and testing sets.
#
# Use:
#
# - **80% data for training**
# - **20% data for testing**
# - `random_state=42`
#
# Make sure that the class distribution is preserved during the split.
#
# ### Question
#
# Which parameter of `train_test_split()` can be used to preserve the class distribution?

# %%
# TODO: Perform train-test split

# %% [markdown]
# ## Task 3 — Train a Linear SVM
#
# Train an SVM model using a **linear kernel**.
#
# ```python
# SVC(kernel="linear")
# ```
#
# Evaluate the model using:
#
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - Confusion Matrix
#
# ### Questions
#
# 1. How well does the linear SVM classify the defective panels?
# 2. Is the linear decision boundary sufficient for this dataset?
# 3. Which metric is most important for detecting defective products?

# %%
# TODO: Train and evaluate a Linear SVM

# %% [markdown]
# ## Task 4 — Use an RBF Kernel
#
# A factory engineer says:
#
# > "Some defective panels appear to be mixed with good panels. A straight decision boundary may not be sufficient."
#
# Train another SVM using:
#
# ```python
# SVC(kernel="rbf")
# ```
#
# Compare it with the Linear SVM.
#
# Create a table similar to:
#
# | Model | Accuracy | Precision | Recall | F1-score |
# |---|---:|---:|---:|---:|
# | Linear SVM | | | | |
# | RBF SVM | | | | |
#
# ### Questions
#
# 1. Which model performs better?
# 2. Why can an RBF kernel handle more complex relationships than a linear kernel?
# 3. Does a more complex model always guarantee better test performance?

# %%
# TODO: Train and compare RBF SVM with Linear SVM

# %% [markdown]
# ## Task 5 — Feature Scaling
#
# The features in the factory dataset may have different numerical ranges.
#
# For example:
#
# - Temperature may be around `100–300`
# - Thickness may be around `0.1–2`
# - Pixel error count may be around `0–1000`
#
# ### Task
#
# Train the SVM:
#
# 1. Without feature scaling
# 2. With `StandardScaler`
#
# Use a pipeline:
#
# ```python
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler
# from sklearn.svm import SVC
#
# model = Pipeline([
#     ("scaler", StandardScaler()),
#     ("svm", SVC())
# ])
# ```
#
# ### Questions
#
# 1. Why is feature scaling important for SVM?
# 2. What problem can occur if one feature has a much larger numerical range than other features?
# 3. Did scaling improve the performance?

# %%
# TODO: Compare SVM with and without scaling

# %% [markdown]
# ## Task 6 — Tune `C`
#
# The parameter `C` controls the trade-off between:
#
# - having a larger margin
# - correctly classifying training observations
#
# Train SVM models using:
#
# ```python
# C_values = [0.01, 0.1, 1, 10, 100]
# ```
#
# For every value of `C`, record:
#
# - Training accuracy
# - Testing accuracy
# - Number of support vectors
#
# Create a result table.
#
# ### Questions
#
# 1. What happens when `C` is very small?
# 2. What happens when `C` is very large?
# 3. Which value gives the best generalization?
# 4. Does a larger `C` mean stronger or weaker regularization?

# %%
# TODO: Compare multiple C values

# %% [markdown]
# ## Task 7 — Tune `gamma`
#
# For an RBF kernel, `gamma` controls how far the influence of each training observation extends.
#
# Train SVM models using:
#
# ```python
# gamma_values = [0.001, 0.01, 0.1, 1, 10]
# ```
#
# Keep other parameters fixed.
#
# Record:
#
# - Training accuracy
# - Testing accuracy
# - Number of support vectors
#
# ### Questions
#
# 1. What happens when `gamma` is very small?
# 2. What happens when `gamma` is very large?
# 3. Which value appears to underfit?
# 4. Which value appears to overfit?

# %%
# TODO: Compare multiple gamma values

# %% [markdown]
# ## Task 8 — Hyperparameter Tuning Using GridSearchCV
#
# Use `GridSearchCV` to find the best combination of:
#
# ```python
# C = [0.01, 0.1, 1, 10, 100]
# gamma = [0.001, 0.01, 0.1, 1]
# kernel = ["linear", "rbf"]
# ```
#
# Use:
#
# ```python
# cv=5
# ```
#
# Report:
#
# - Best kernel
# - Best `C`
# - Best `gamma`
# - Best cross-validation score
# - Final test accuracy
#
# ### Important
#
# Do not use the test set to select the hyperparameters.

# %%
# TODO: Perform GridSearchCV

# %% [markdown]
# ## Task 9 — Inspect Support Vectors
#
# Retrieve the support vectors from your final SVM model.
#
# Answer:
#
# 1. How many support vectors are present?
# 2. What percentage of the training dataset are support vectors?
# 3. Why are these observations called **support vectors**?
# 4. Are all training observations equally important for defining the SVM decision boundary?
# 5. What may happen if one important support vector is removed?

# %%
# TODO: Inspect support vectors

# %% [markdown]
# ## Task 10 — Factory Error Analysis
#
# The factory manager is especially concerned about the following situation:
#
# > A defective display is classified as **Good** and shipped to a customer.
#
# Using the confusion matrix:
#
# 1. Identify which type of error this represents.
# 2. Is it:
#    - False Positive
#    - False Negative
# 3. Which metric should receive more attention in this case?
#    - Accuracy
#    - Precision
#    - Recall
#    - F1-score
#
# Explain your answer from the factory's point of view.

# %%
# TODO: Analyze confusion matrix and error type

# %% [markdown]
# ## Task 11 — Handle Class Imbalance
#
# The dataset contains many more good panels than defective panels.
#
# Compare:
#
# ```python
# SVC(kernel="rbf")
# ```
#
# with:
#
# ```python
# SVC(
#     kernel="rbf",
#     class_weight="balanced"
# )
# ```
#
# Compare:
#
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - Confusion Matrix
#
# ### Question
#
# Does `class_weight="balanced"` improve the detection of defective panels?
#
# Explain the trade-off.

# %%
# TODO: Compare default and class_weight='balanced'

# %% [markdown]
# ## Task 12 — Extreme `C` Values
#
# Train two RBF SVM models:
#
# ```python
# C = 0.01
# ```
#
# and
#
# ```python
# C = 1000
# ```
#
# Compare:
#
# - Training accuracy
# - Testing accuracy
# - Number of support vectors
#
# ### Questions
#
# For each model, discuss:
#
# - Margin size
# - Training errors
# - Model complexity
# - Regularization
# - Risk of underfitting
# - Risk of overfitting

# %%
# TODO: Compare extreme C values

# %% [markdown]
# ## Task 13 — Extreme `gamma` Values
#
# Train:
#
# ```python
# gamma = 0.001
# ```
#
# and
#
# ```python
# gamma = 100
# ```
#
# using an RBF SVM.
#
# Compare training and testing performance.
#
# ### Questions
#
# 1. Which model is more likely to underfit?
# 2. Which model is more likely to overfit?
# 3. Why does very large `gamma` make the influence of a training point highly local?

# %%
# TODO: Compare extreme gamma values

# %% [markdown]
# ## Task 14 — Decision Function
#
# Use:
#
# ```python
# model.decision_function(X_test)
# ```
#
# For at least 10 test samples, display:
#
# - True label
# - Predicted label
# - Decision score
#
# ### Questions
#
# 1. Which observations are closest to the decision boundary?
# 2. What does a large positive decision score indicate?
# 3. What does a large negative decision score indicate?
# 4. Is the decision score a probability?

# %%
# TODO: Inspect decision function scores

# %% [markdown]
# ## Task 15 — Compare SVM with Logistic Regression
#
# Train:
#
# ```python
# LogisticRegression()
# ```
#
# and compare it with your best SVM model.
#
# Compare:
#
# - Accuracy
# - Precision
# - Recall
# - F1-score
#
# Also discuss:
#
# - Decision-boundary flexibility
# - Interpretability
# - Computational cost
# - Ability to handle nonlinear relationships
#
# ### Final Question
#
# Is it correct to say:
#
# > "SVM is always better than Logistic Regression."
#
# Justify your answer.

# %%
# TODO: Compare Logistic Regression with the best SVM

# %% [markdown]
# ## Bonus Task — Multiclass Extension
#
# The company changes its quality-control system and now assigns three labels:
#
# - **0 → Good**
# - **1 → Minor Defect**
# - **2 → Critical Defect**
#
# Answer the following:
#
# 1. Can SVM still be used?
# 2. SVM was originally designed for binary classification. How can it solve a multiclass problem?
# 3. Explain:
#    - One-vs-Rest
#    - One-vs-One
# 4. If there are `3` classes, how many classifiers are required in One-vs-One?
# 5. If there are `10` classes, how many classifiers would be required?
#
# Use:
#
# \[
# \frac{K(K-1)}{2}
# \]
#
# for `K` classes.

# %%
# TODO: Optional multiclass experiment
