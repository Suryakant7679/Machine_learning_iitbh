# %% [markdown]
# # Assignment: Bias–Variance, Regularization, and Logistic Regression

# %% [markdown]
# ## Assignment objective
#
# In this assignment, you will apply the concepts covered in the lab to datasets selected by you.
#
# You must choose:
#
# 1. **One regression dataset** for Bias–Variance and Regularization.
# 2. **One binary-classification dataset** for Logistic Regression.
#
# You may obtain datasets from scikit-learn, OpenML, Kaggle, UCI, or another reliable source.
